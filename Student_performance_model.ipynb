# %%
import pandas as pd

# %%
data = {
    "StudyHours": [15, 5, 10, 12, 8, 3, 14, 6, 2, 11, 9, 7, 1, 13, 4, 16, 10, 5, 9, 6],
    "Attendance": [92, 60, 75, 85, 70, 50, 90, 65, 40, 80, 73, 66, 35, 88, 55, 95, 72, 60, 78, 68],
    "PreviousGrade": [88, 55, 70, 78, 68, 40, 82, 60, 35, 76, 69, 65, 30, 84, 50, 90, 72, 58, 75, 63],
    "Performance": ["High", "Low", "Medium", "High", "Medium", "Low", "High", "Medium", "Low",
                    "High", "Medium", "Medium", "Low", "High", "Low", "High", "Medium", "Low", "Medium", "Medium"]
}

# %%
df= pd.DataFrame(data)

# %%
df.to_csv("Student_data.csv", index = False)

# %%
student_date = pd.read_csv("Student_data.csv")
student_data
# Out:
#     StudyHours  Attendance  PreviousGrade Performance
# 0           15          92             88        High
# 1            5          60             55         Low
# 2           10          75             70      Medium
# 3           12          85             78        High
# 4            8          70             68      Medium
# 5            3          50             40         Low
# 6           14          90             82        High
# 7            6          65             60      Medium
# 8            2          40             35         Low
# 9           11          80             76        High
# 10           9          73             69      Medium
# 11           7          66             65      Medium
# 12           1          35             30         Low
# 13          13          88             84        High
# 14           4          55             50         Low
# 15          16          95             90        High
# ...

# %%
X = student_data.drop(columns = ["Performance"])

# %%
y = student_data["Performance"]

# %%
X
# Out:
#     StudyHours  Attendance  PreviousGrade
# 0           15          92             88
# 1            5          60             55
# 2           10          75             70
# 3           12          85             78
# 4            8          70             68
# 5            3          50             40
# 6           14          90             82
# 7            6          65             60
# 8            2          40             35
# 9           11          80             76
# 10           9          73             69
# 11           7          66             65
# 12           1          35             30
# 13          13          88             84
# 14           4          55             50
# 15          16          95             90
# 16          10          72             72
# 17           5          60             58
# 18           9          78             75
# 19           6          68             63

# %%
y
# Out:
# 0       High
# 1        Low
# 2     Medium
# 3       High
# 4     Medium
# 5        Low
# 6       High
# 7     Medium
# 8        Low
# 9       High
# 10    Medium
# 11    Medium
# 12       Low
# 13      High
# 14       Low
# 15      High
# 16    Medium
# 17       Low
# 18    Medium
# 19    Medium
# Name: Performance, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X, y, test_size = 0.25, random_state =0)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\Users\HP\Downloads\New folder\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(

# %%
import pickle
pickle.dump(model, open("student_performance_prediction.pkl", "wb"))
model1 = pickle.load(open("student_performance_prediction.pkl", "rb"))

# %%
print(model.predict([[12, 60, 70]]))  # Note the double brackets
# Out:
# ['Medium']
# C:\Users\HP\Downloads\New folder\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
